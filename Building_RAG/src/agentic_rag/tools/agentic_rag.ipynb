# %%
# !pip install "chonkie[semantic]"
# !pip install markitdown
# !pip install qdrant-client
# !pip install astembed
# Out:
# Collecting chonkie[semantic]
#   Could not fetch URL https://pypi.python.org/simple/chonkie/: There was a problem confirming the ssl certificate: [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:581) - skipping
#   Could not find a version that satisfies the requirement chonkie[semantic] (from versions: )
# No matching distribution found for chonkie[semantic]
# Collecting markitdown
#   Could not fetch URL https://pypi.python.org/simple/markitdown/: There was a problem confirming the ssl certificate: [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:581) - skipping
#   Could not find a version that satisfies the requirement markitdown (from versions: )
# No matching distribution found for markitdown
# Collecting qdrant-client
#   Could not fetch URL https://pypi.python.org/simple/qdrant-client/: There was a problem confirming the ssl certificate: [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:581) - skipping
#   Could not find a version that satisfies the requirement qdrant-client (from versions: )
# No matching distribution found for qdrant-client
# Collecting astembed
#   Could not fetch URL https://pypi.python.org/simple/astembed/: There was a problem confirming the ssl certificate: [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:581) - skipping
#   Could not find a version that satisfies the requirement astembed (from versions: )
# No matching distribution found for astembed

# %%
from crewai import Agent, Crew, Process, Task
from crewai.project import Crewbase, agent, crew, task
from crewai_tools import SerperDevTool
from crewai_tools import PDFSearchTool
#from tools.custom_tools import DocumentSearchTool
from tools.custom_tool import DocumentSearchTool
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from crewai import Agent, Crew, Process, Task
#       2 from crewai.project import Crewbase, agent, crew, task
#       3 from crewai_tools import SerperDevTool
#
# ModuleNotFoundError: No module named 'crewai'
